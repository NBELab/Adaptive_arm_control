# %% [markdown]
# ### kinematics for the ViperX 300 6DOF by Trossen Robotics
# #### By Elishai Ezra Tsur

# %%
from IK import *

arm   = viper300()
q, trajectory, error_tract, xyz_t = goto_target(arm, np.array([[-0.25, 0.25, 0.25]]).T, optimizer = Optimizer.DLS)
# Out:
# Arm config: [[-38  18   8   0   3]], with error: 0.0009148776060693321, achieved @ step: 60

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# Plot EE convergence to target -------------------------------------------------------
plt.figure()
plt.ylabel("Distance (m)")
plt.xlabel("Time (ms)")
plt.title("Distance to target")
plt.plot(error_tract)
plt.show()

# Plot EE trajectory ------------------------------------------------------------------
ax = plt.figure().add_subplot(111, projection='3d')
ee_x = [ee[0][0] for ee in trajectory]
ee_y = [ee[1][0] for ee in trajectory]
ee_z = [ee[2][0] for ee in trajectory]

ax.set_title("End-Effector Trajectory")
ax.plot(ee_x, ee_y, ee_z)
ax.scatter(xyz_t[0], xyz_t[1], xyz_t[2], label="target", c="r")
ax.legend()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;matplotlib.legend.Legend at 0x2177edf3a88&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
